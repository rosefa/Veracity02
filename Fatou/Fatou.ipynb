# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Github/
# %cd Veracity
#!pip install tensorflow_decision_forests
# !pip install wget
# !pip install pysbd
# !pip install contractions
# !pip install textsearch
# !pip install tqdm
# !pip install stop-words
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/Veracity
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=45d8bc3743d7c28224789f9e56a3aebdad1a90d8386cb05a11531eeacc10b3a3
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 KB 7.6 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 KB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.5/104.5 KB 11.9 MB/s eta 0:00:00
# ...

# %%
# !python prediction.py
# Out:
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-02-10 16:15:31.952760: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading PorterStemmer: Package 'PorterStemmer' not
# [nltk_data]     found in index
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [[ 38 340]
#  [ 30 396]]
# 0.5398009950248757
# 0.5380434782608695
# 0.9295774647887324
# 0.6815834767641996

# %%
# %cd /content/drive/MyDrive/Github/
# %cd Veracity
# %cd Fatou
value = np.loadtxt("valueFakes2.txt")
valuePre = np.loadtxt("valuePreFakes2.txt")
# Out:
# /content/drive/MyDrive/Github
# /content/drive/MyDrive/Github/Veracity
# /content/drive/MyDrive/Github/Veracity/Fatou

# %%
cf_matrix = confusion_matrix(value, valuePre)
disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix,display_labels=[False, True])
disp.plot()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-009a6812470a> in <module>
# ----> 1 make_confusion_matrix(cf_matrix, figsize=(6,6), cbar=False, title='Confusion Matrix')
#
# NameError: name 'make_confusion_matrix' is not defined

# %%
pip install cf_matrix
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement cf_matrix (from versions: none)
# ERROR: No matching distribution found for cf_matrix
